# %%
import sys
sys.path.append(r"C:\Users\Fandingo\Documents\Cohort\Week_10\Automated_Storyboard_Synthesis_for_Digital_Advertising\Automated-Storyboard-for-Digital-Ad")
import Utils.image_composition
import cv2
import matplotlib.pyplot as plt

# %%
image1 = cv2.imread('C:\\Users\\Fandingo\\Documents\\Cohort\\Week_10\\Automated_Storyboard_Synthesis_for_Digital_Advertising\\Automated-Storyboard-for-Digital-Ad\\Notebook\\images\\back.png')
image2 = cv2.imread('C:\\Users\\Fandingo\\Documents\\Cohort\\Week_10\\Automated_Storyboard_Synthesis_for_Digital_Advertising\\Automated-Storyboard-for-Digital-Ad\\Notebook\\images\\out-0_0.png')
plt.imshow(image1)

# %%
plt.imshow(image2)

# %%
image2 = cv2.resize(image2,(300,224))
img = Utils.image_composition.image_overlay(image1,image2,location=(200,800))
plt.imshow(img)
