# %%
import sys
sys.path.append(r"C:\Users\Fandingo\Documents\Cohort\Week_10\Automated_Storyboard_Synthesis_for_Digital_Advertising\Automated-Storyboard-for-Digital-Ad")
import Utils.image_composition
import cv2
import matplotlib.pyplot as plt

# %%
image1 = cv2.imread('C:\\Users\\Fandingo\\Documents\\Cohort\\Week_10\\Automated_Storyboard_Synthesis_for_Digital_Advertising\\Automated-Storyboard-for-Digital-Ad\\Notebook\\images\\endframe.png')
image2 = cv2.imread('C:\\Users\\Fandingo\\Documents\\Cohort\\Week_10\\Automated_Storyboard_Synthesis_for_Digital_Advertising\\Automated-Storyboard-for-Digital-Ad\\Notebook\\images\\fr-2-copy.png')


img = Utils.image_composition.image_overlay(image1,image2,location=(100,100))
plt.imshow(img)
